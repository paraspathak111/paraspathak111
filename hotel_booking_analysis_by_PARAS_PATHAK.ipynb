# %% [markdown]
# <a href="https://colab.research.google.com/github/paraspathak111/paraspathak111/blob/main/hotel_booking_analysis_by_PARAS_PATHAK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Paras Pathak

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The hotel booking dataset contains booking information for city and resort hotel. This dataset has 1,19,390 observations and 31 variables. Each observation represent a hotel booking. This hotel booking dataset comprehenses booking due to arrive between 1st of july of 2015 and 31st august of 2017, including booking that effectively arrived and booking that were cancelled.
#
# our analysis can help you to understand about given data and draw some meaningful insights so that you can make some business related crucial decisions with this analysis. some factors dafinately going to play a important role in it like cancelling and average daily rate.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# We are here to explore the hotel booking dataset to get some important factors related to booking information. With that insights, client get some help to understand the loopholes. We also analyze more aspect of hotel booking dataset
# like hotel type, country, booking timing etc.
#
#
# *  The time of year is to book hotel?
# *  To predict whether or not a hotels was not likely to recieve high number of booking?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# *   Give suggestion to reduce cancelled booking.
#
# *   Make plan to grow business in near future.
# *   Explain them briefly.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   There are 31 columns and 119930 rows in given dataset.
#
# *   4 columns have null values: company(112593), agent(16340), country(488) and children(4).

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# hotel : types of hotel(city and resort hotel)
#
# is_canceled : canceled booking (1 or 0)
#
# lead_time : Number of days elapsed between entering date and arrival data
#
# arrival_date_year : Year of arrival
#
# arrival_date_month : month of arrival
#
# arrival_date_week_number : week of arrival
#
# arrival_date_day_of_month : day of arrival
#
# stays_in_weekend_nights : Number of weekend nights(saturday or sunday)
#
# stays_in_week_nights : Number of week nights
#
# adults : number of adults
#
# children : number of children
#
# babies : number of babies
#
# meal : kind of meal
#
# country : country code
#
# market_segment : different types of market segment
#
# distribution_channel : how the customer access the channel
#
# is_repeated_guest : number of repeated guest
#
# previous_cancellations : number of previous cancellation
#
# previous_bookings_not_canceled : number of not cancelled booking
#
# reserved_room_type : types of reserved room
#
# assigned_room_type : number of assigned room type
#
# booking_changes : count of booking changes
#
# deposit_type : deposit type
#
# agent : booking through agent
#
# company : types of company
#
# days_in_waiting_list : number of waiting list
#
# customer_type : types of customer
#
# adr : number of adr
#
# required_car_parking_spaces : car parking status
#
# total_of_special_requests : if any special requests
#
# reservation_status : types of reservation status
#
# reservation_status_date : date of reservation status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. Checking and handling missing value

# %% [markdown]
# ### Data Wrangling Code

# %%
# sum of null values in dataset
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# checking unique value in children column
df['children'].isnull().value_counts()
# Out:
# False    119386
# True          4
# Name: children, dtype: int64

# %%
# checking unique value in country column
df['country'].isnull().value_counts()
# Out:
# False    118902
# True        488
# Name: country, dtype: int64

# %%
# checking unique value in agent column
df['agent'].isnull().value_counts()
# Out:
# False    103050
# True      16340
# Name: agent, dtype: int64

# %%
# checking unique value in company column
df['company'].isnull().value_counts()
# Out:
# True     112593
# False      6797
# Name: company, dtype: int64

# %%
# droping null values in children column
df.dropna(subset='children',inplace=True)

# %%
# droping null values in country column
df.dropna(subset='country',inplace=True)

# %%
#filling values in agent column
df['agent']=df['agent'].fillna(0)

# %%
# filling values in company column
df['company']=df['company'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118898 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %% [markdown]
# There is no null value in dataset now.

# %%
#checking unique values in market_segment
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment']=df['market_segment'].replace(to_replace='Undefined',value='Online TA')
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
#adding all nights togther
df['total_nights']=df['stays_in_weekend_nights']+df['stays_in_week_nights']

# %%
#combing the total number people
df['total_people']=df['adults']+df['babies']+df['children']

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Analysis of Hotel basis of count

# %%
# using countplot for analysis
sns.countplot(data=df,x='hotel')
plt.title('analysis of hotel')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   City Hotel has more numbers of booking compare to Resort Hotel.

# %% [markdown]
# #### Chart - 2 Analysis of different types of customer

# %%
df['customer_type'].value_counts()
# Out:
# Transient          89174
# Transient-Party    25078
# Contract            4076
# Group                570
# Name: customer_type, dtype: int64

# %%
# using pie chart
fig = plt.figure(figsize=(5,5), dpi=100)
df['customer_type'].value_counts().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=12)
# Out:
# <Axes: ylabel='customer_type'>

# %% [markdown]
# Observation:
#
#
#
#
# *   Transient has more customer base among all customer types.
# *   After Transient, transient-party has more customers.

# %% [markdown]
# #### Chart - 3 Analysis of Booking Information

# %%
# using bar chart
df2= df['is_canceled'].value_counts()
x=df2.index.values
y=df2.values
plt.figure(figsize=(10,5))
plot=sns.barplot(x=x,y=y/sum(y)*100)
plt.xlabel('Booking cancelled(booking cancelled = 1, Not cancelled= 0)')
plt.ylabel('Percentage of bookking')
plt.title('Booking information(cancelled or Not)')
plt.show()

# %% [markdown]
# Observation:
#
#
#
# *   Percentage of booking cancelled is more than booking not cancelled booking.

# %% [markdown]
# #### Chart - 4 Booking basis of hotel type

# %%
# using bar plot
df3= df['hotel'].value_counts()
x= df3.index
y= df3.values
plt.figure(figsize=(10,5))
plot=sns.barplot(x=x,y=y/sum(y)*100)
plt.xlabel('Types of hotels')
plt.ylabel('Percentage of booking')
plt.title('Booking basis of hotel type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   City hotel has more percentage of booking than Resort hotel.

# %% [markdown]
# #### Chart - 5 Booking of guests from different country

# %%
# using bar chart
df4=df['country'].value_counts().head(15)
x=df4.index
y=df4.values
plt.figure(figsize=(10,5))
plot=sns.barplot(x=x,y=y/sum(y)*100)
plt.xlabel('country')
plt.ylabel('Percentage of booking')
plt.title('Booking of guests from different country')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   Top 5 countries basis of percentage of booking are:
#      1. PRT
#      2. GBR
#      3. FRA
#      4. ESP
#      5. DEU

# %% [markdown]
# #### Chart - 6 Booking for reserved type

# %%
#using bar chart
df5=df['reserved_room_type'].value_counts()
x=df5.index
y=df5.values
plt.figure(figsize=(10,5))
plot=sns.barplot(x=x,y=y/sum(y)*100)
plt.xlabel('Booking type')
plt.ylabel('Percentage of booking')
plt.title('Booking for reserved type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   Booking type A has most number of booking among all booking type.

# %% [markdown]
# #### Chart - 7 Analysis of arrival date months

# %%
#using bar chart in this analysis
df6=df['arrival_date_month'].value_counts()
x=df6.index
y=df6.values
plt.figure(figsize=(10,5))
plot=sns.barplot(x=x,y=y/sum(y)*100)
plt.xlabel('Months')
plt.ylabel('Percentage of booking')
plt.title('Booking for arrival date months')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   August has hightest percentage of booking among all months.
# *   January has lowest percentage of booking among all months.

# %% [markdown]
# #### Chart - 8 Analysis on total nights

# %%
# Using countplot for analysis
df['same_room_assigned']=df['reserved_room_type']==df['assigned_room_type']
plt.figure(figsize=(12,8))
sns.countplot(x=df['total_nights'],hue=df['same_room_assigned'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation:
#
#
#
# *   from above chart, it is clear that customer prefer same room assigned of that particular nights.

# %% [markdown]
# #### Chart - 9 Analysis of market segment

# %%
# using Pie chart
fig = plt.figure(figsize=(5,5), dpi=100)
df['market_segment'].value_counts().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=10)
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %% [markdown]
# Observation:
#
#
#
# *   Online TA has hightest number of booking in market.
# *   Offline TA/TO has second hightest number of booking in the market.

# %% [markdown]
# #### Chart - 10 Analysis of hotel type in basis of total nights

# %%
# using histplot
temp_df=df[df['is_canceled']==0]
temp_15=temp_df[temp_df['total_nights']<15]
plt.figure(figsize=(10,5))
plt.title('')
sns.histplot(x=temp_df['total_nights'],bins=20,alpha=0.7,hue=temp_15['hotel'])
# Out:
# <Axes: xlabel='total_nights', ylabel='Count'>

# %% [markdown]
# Observation:
#
#
#
# *   City hotel has more number of booking in 1 and 2 nights compare to Resort hotel.

# %% [markdown]
# #### Chart - 11 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-4-5c20c5e2b68a>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# Observation:
#
#
#
# *   There is no such corelation between these variables.

# %% [markdown]
# #### Chart - 12 Market segment vs Total Nights

# %%
# Scatter Plot visualization code

a, ax = plt.subplots(figsize=(12, 5))
fig = sns.scatterplot(x='market_segment', y='total_nights', data=df)
plt.title('Analysis of market segment')
# Out:
# Text(0.5, 1.0, 'Analysis of market segment')

# %% [markdown]
# Observation:
#
#
#
# *   Online TA has most number of total nights booking compare to all market type.
# *   Aviation has least number of total nighhts booking.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Based on data analysis, here are some suggestions to achieve business growth :
#
# 1. cancellation policies - To achieve business growth in near future, you need to start making strict cancellation policies and understand the main reason behind cancelled booking by customer.
# 2. Deposit type - Availability in all deposit type can make business grow more faster in near future. Specially availabiity in online booking like UPI and netbanking can make a difference other competitor.
# 3. Off-peak month - Business should focus on off-peak month like Jan and december because of new year and christmas. They should provide available discount to increase sales in that months.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, based on exploratory data analysis(eda) several data insights and recommendations have indentified to improve business :
#
# 1. Hotel Type - City hotel has more number of booking compare to resort hotel and city hotel had more number of booking at night compare to resort hotel. Resort hotel should give some discounts to increase thier total hotel booking.
# 2. seasonality - August and july has highest booking amongs months but jan and dec had lowest number of booking. Jan and Dec are seasonal months because of new year and festive. To increase booking in seasonal months you need to allow group booking for customer.
# 3. Cancellation - In this given dataset cancelled booking are less than compare to not cancelled booking. for that business should ask customers why they cancelled booking? through feedback form and they apply some strict rule on cancelled booking.
# 4. Market segment - Online TA has more customer among all other market segments that means customer are more intrest through  online so business should now focus more on online platform.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
